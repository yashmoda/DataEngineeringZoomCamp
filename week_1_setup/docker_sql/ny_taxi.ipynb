# %%
import pandas as pd
import sqlalchemy

# %%
db_engine = sqlalchemy.create_engine('postgresql://root:root@localhost:5432/ny_taxi')
connection = db_engine.connect()

# %%
trip_df = pd.read_csv('green_tripdata_2019-01.csv')
trip_df.shape
# Out:
# (630918, 20)

# %%
trip_df['lpep_pickup_datetime'] = pd.to_datetime(trip_df['lpep_pickup_datetime'])
trip_df['lpep_dropoff_date'] = pd.to_datetime(trip_df['lpep_dropoff_datetime'])
trip_df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1         2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2         2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3         2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4         2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1           264           264                5           0.00
# 1           1            97            49                2           0.86
# 2           1            49           189                2           0.66
# 3           1           189            17                2           2.68
# 4           1            82           258                1           4.53
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
print(pd.io.sql.get_schema(trip_df, 'green_taxi_data', con=db_engine))
# Out:
# CREATE TABLE green_taxi_data (
# 	"VendorID" BIGINT,
# 	lpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	lpep_dropoff_datetime TEXT,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" BIGINT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type BIGINT,
# 	trip_type BIGINT,
# 	congestion_surcharge FLOAT(53),
# 	lpep_dropoff_date TIMESTAMP WITHOUT TIME ZONE
# )

# %%
trip_df.to_sql(name='green_taxi_data', con=db_engine, if_exists='replace')
# Out:
# 918

# %%
zone_df = pd.read_csv('taxi+_zone_lookup.csv')
zone_df.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
print(pd.io.sql.get_schema(zone_df, 'zone_data', con=db_engine))
# Out:
# CREATE TABLE zone_data (
# 	"LocationID" BIGINT,
# 	"Borough" TEXT,
# 	"Zone" TEXT,
# 	service_zone TEXT
# )

# %%
# %time zone_df.to_sql(name='zone_data', con=db_engine, if_exists='replace')
# Out:
# CPU times: user 7.86 ms, sys: 8.31 ms, total: 16.2 ms
# Wall time: 170 ms
# 265

# %%
# Out:
# ...
#      |████████████████████████████████| 384 kB 1.8 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/yashmoda/Projects/DataEngineeringZoomCamp/venv/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/md/xsbrn6c93kb_355dgk5rw9780000gn/T/pip-install-ln7euive/psycopg2_6133b18ed4e849f8a20f7dc5815654cd/setup.py'"'"'; __file__='"'"'/private/var/folders/md/xsbrn6c93kb_355dgk5rw9780000gn/T/pip-install-ln7euive/psycopg2_6133b18ed4e849f8a20f7dc5815654cd/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/md/xsbrn6c93kb_355dgk5rw9780000gn/T/pip-pip-egg-info-anh84j7k
# ...
